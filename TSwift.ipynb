# %%
.ORIG x3000
.SET MODE TERMINAL

LEA R1, ARRAYQ
LDR R0, R1, #0
PUTSP
TRAP x23
ST R0, ANS1

LDR R0, R1, #1
PUTSP
TRAP x23
ST R0, ANS2

LDR R0, R1, #2
PUTSP
TRAP x23
ST R0, ANS3

LDR R0, R1, #3
PUTSP
TRAP x23
ST R0, ANS4

LDR R0, R1, #4
PUTSP
TRAP x23
ST R0, ANS5

LDR R0, R1, #5
PUTSP
TRAP x23
ST R0, ANS6

JSR ADDFUNC
AND R3, R3, #0
ADD R3, R3, #-15
ADD R3, R3, #-15
ADD R3, R3, #-2
AND R4, R4, #0
ADD R4, R0, R3
BRzp REPUTATION
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp NINETEEN
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp RED
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp SPEAKNOW
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp FEARLESS
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp TAYLORSWIFT
HALT

TAYLORSWIFT: LEA R1, ARRAYQ
             LDR R0, R1, #6
             PUTSP
             LEA R0, HEADER
             TERMINAL R0, 0
             HALT
             
FEARLESS:    LEA R1, ARRAYQ
             LDR R0, R1, #7
             PUTSP
             LEA R0, HEADER2
             TERMINAL R0, 0
             HALT
             
SPEAKNOW:    LEA R1, ARRAYQ
             LDR R0, R1, #8
             PUTSP
             ;LEA R0, HEADER3
             ;TERMINAL R0, 0
             HALT 
RED:         LEA R1, ARRAYQ
             LDR R0, R1, #9
             PUTSP
             ;LEA R0, HEADER4
             ;TERMINAL R0, 0
             HALT
NINETEEN:    LEA R1, ARRAYQ
             LDR R0, R1, #10
             PUTSP
             ;LEA R0, HEADER5
             ;TERMINAL R0, 0
             HALT             
REPUTATION:  LEA R1, ARRAYQ
             LDR R0, R1, #11
             PUTSP
             ;LEA R0, HEADER6
             ;TERMINAL R0, 0
             HALT

ANS1: .FILL    #0
ANS2: .FILL    #0
ANS3: .FILL    #0
ANS4: .FILL    #0
ANS5: .FILL    #0
ANS6: .FILL    #0

ARRAYQ: .FILL Q1
        .FILL Q2 
        .FILL Q3
        .FILL Q4
        .FILL Q5
        .FILL Q6
        .FILL A1 
        .FILL A2
        .FILL A3
        .FILL A4
        .FILL A5
        .FILL A6
        
HEADER: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/1/1f/Taylor_Swift_-_Taylor_Swift.png', width=300>"
HEADER2: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/8/86/Taylor_Swift_-_Fearless.png', width=300>"
;HEADER3: .STRINGZ "<img src='https://www.billboard.com/files/styles/900_wide/public/media/taylor-swift-speak-now-album-cover-2010-billboard-600x600.jpg', width=300>"
;HEADER4: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/e/e8/Taylor_Swift_-_Red.png', width=300>"
;HEADER5: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/f/f6/Taylor_Swift_-_1989.png', width=300>"
;HEADER6: .STRINGZ "<img src='https://www.billboard.com/files/media/Taylor-Swift-reputation-ART-2017-billboard-1548.jpg', width=300>"

ASCII: .FILL   #-48

ASCIIFUNC: LD R1, ANS1, #0
           LD R2, ANS2, #0
           LD R3, ANS3, #0
           LD R4, ANS4, #0
           LD R5, ANS5, #0
           LD R6, ANS6, #0
           
           LD R0, ASCII, #0
           ADD R1, R1, R0
           ADD R2, R2, R0
           ADD R3, R3, R0
           ADD R4, R4, R0
           ADD R5, R5, R0
           ADD R6, R6, R0
           RET

Q1 .STRINGC "What would your ideal Friday night look like? \n 1. Go to local corn maze \n 2. Chill with Abigail at the Homecoming \n 3. Watch Twilight with your boyfriend \n 4. Hit up a One Direction Concert in London \n 5. Hang with your girl squad \n 6. Plot revenge on your enemies \n"
Q2 .STRINGC "\n What is your favorite color? \n 1. pink \n 2. yellow \n 3. purple \n 4. red \n 5. Anything Sepia toned \n 6. black \n"
Q3 .STRINGC "\n Which boyfriend would give you the best lyric material? \n 1. My high school crush \n 2. Joe Jonas \n 3. Taylor Lautner \n 4. Harry Styles \n 5. Calvin Harris \n 6. Do not need a boyfriend for good material! \n"
Q4 .STRINGC "\n Who would be your best friend in another life? \n 1. My mom \n 2. Abigail \n 3. Ellen Degeneres \n 4. Selena Gomez \n 5. Karlie Kloss \n 6. I do not have any friends \n"
Q5 .STRINGC "\n What is your favorite cookie flavor? \n 1. Sugar Cookies \n 2. Chocolate Chip \n 3. Peanut butter Cookie \n 4. Red Velvet \n 5. Snickerdoodle \n 6. Ginger Snap \n"
Q6 .STRINGC "\n Where do you want to live? \n 1. My hometown! \n 2. Nashville \n 3. Los Angeles \n 4. Rhode Island \n 5. New York City \n 6. London \n"

A1 .STRINGC "\n You are: Taylor Swift \n”
A2 .STRINGC "\n You are: Fearless \n”
A3 .STRINGC "\n You are: Speak Now \n”
A4 .STRINGC "\n You are: Red \n”
A5 .STRINGC "\n You are: 1989 \n”
A6 .STRINGC "\n You are: Reputation \n”

; STACK
TOP:    .FILL    STACK
STACK:  .BLKW    #100
REG2:   .FILL    #0
REG5:   .FILL    #0
REG6:   .FILL    #0
REG7:   .FILL    #0

PUSH:  ST R2, REG2
       ST R5, REG5
       ST R6, REG6
       LEA R2, STACK
       ST R2, TOP
       LD R6, TOP            ;; R6 is now TOP of stack
       LD R5, REG7, #0
       STR R5, R6, #0        ;; push R7 on stack (R6 is top of stack location)
       ADD R6, R6, #1        ;; incr
       ST R6, TOP            ;; save incremented TOP
       LD R2, REG2
       LD R5, REG5
       LD R6, REG6
       RET
      
POP:   ST R5, REG5
       ST R6, REG6
       LD R6, TOP          ;; R6 is TOP of stack
       ADD R6, R6, #-1     ;; decr
       LDR R5, R6, #0      ;; load into R7 into R3
       ST R5, REG7, #0     ;; put value of R7 into REG7
       ADD R6, R6, #-1     ;; decr
       ST R6, TOP          ;; save decremented TOP
       LD R5, REG5
       LD R6, REG6
       RET  

ADDFUNC: ST R7, REG7, #0
         JSR PUSH
         JSR ASCIIFUNC
         AND R0, R0, #0
         ADD R0, R1, #0
         ADD R0, R2, R0
         ADD R0, R3, R0
         ADD R0, R4, R0
         ADD R0, R5, R0
         ADD R0, R6, R0
         ;ST R0, SUM
        
         JSR POP
         LD R7, REG7, #0
         RET

.END
# Out:
# Assembled! Use %dis or %dump to examine; use %exe to run.

# %%
%exe
# Out:
# What would your ideal Friday night look like?
#  1. Go to local corn maze
#  2. Chill with Abigail at the Homecoming
#  3. Watch Twilight with your boyfriend
#  4. Hit up a One Direction Concert in London
#  5. Hang with your girl squad
#  6. Plot revenge on your enemies
#
# Input a character> 1
# 1
#
#  What is your favorite color?
#  1. pink
#  2. yellow
#  3. purple
#  4. red
#  5. Anything Sepia toned
#  6. black
#
# Input a character> 2
# 2
#
#  Which boyfriend would give you the best lyric material?
#  1. My high school crush
#  2. Joe Jonas
#  3. Taylor Lautner
#  4. Harry Styles
#  5. Calvin Harris
#  6. Do not need a boyfriend for good material! 3
#
#
# Input a character> 3
#
#  Who would be your best friend in another life?
#  1. My mom
#  2. Abigail
#  3. Ellen Degeneres
#  4. Selena Gomez
#  5. Karlie Kloss
#  6. I do not have any friends
#
# Input a character> 4
# 4
#
#  What is your favorite cookie flavor?
#  1. Sugar Cookies
#  2. Chocolate Chip
# ...

# %%
.ORIG x3000
.SET MODE TERMINAL

JSR ADDFUNC
AND R3, R3, #0
ADD R3, R3, #-15
ADD R3, R3, #-15
ADD R3, R3, #-2
AND R4, R4, #0
ADD R4, R0, R3
BRzp REPUTATION
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp NINETEEN
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp RED
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp SPEAKNOW
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp FEARLESS
ADD R3, R3, #6
AND R4, R4, #0
ADD R4, R0, R3
BRzp TAYLORSWIFT
HALT

LEA R1, ARRAYQ
LDI R0, R1, #0
PUTSP
TRAP x23
STI R0, ANS1

LDI R0, R1, #1
PUTSP
TRAP x23
STI R0, ANS2

LDI R0, R1, #2
PUTSP
TRAP x23
STI R0, ANS3

LDI R0, R1, #3
PUTSP
TRAP x23
STI R0, ANS4

LDI R0, R1, #4
PUTSP
TRAP x23
STI R0, ANS5

LDI R0, R1, #5
PUTSP
TRAP x23
STI R0, ANS6

ADDFUNC: STI R7, REG7, #0
         JSR PUSH
         JSR ASCIIFUNC
         AND R0, R0, #0
         ADD R0, R1, #0
         ADD R0, R2, R0
         ADD R0, R3, R0
         ADD R0, R4, R0
         ADD R0, R5, R0
         ADD R0, R6, R0
         ;ST R0, SUM
        
         JSR POP
         LDI R7, REG7, #0
         RET

TAYLORSWIFT: LEA R1, ARRAYQ
             LDR R0, R1, #6
             PUTSP
             LEA R0, HEADER
             TERMINAL R0, 0
             HALT
             
FEARLESS:    LEA R1, ARRAYQ
             LDR R0, R1, #7
             PUTSP
             LEA R0, HEADER2
             TERMINAL R0, 0
             HALT
             
SPEAKNOW:    LEA R1, ARRAYQ
             LDR R0, R1, #8
             PUTSP
             LEA R0, HEADER3
             TERMINAL R0, 0
             HALT 
RED:         LEA R1, ARRAYQ
             LDR R0, R1, #9
             PUTSP
             LEA R0, HEADER4
             TERMINAL R0, 0
             HALT
NINETEEN:    LEA R1, ARRAYQ
             LDR R0, R1, #10
             PUTSP
             LEA R0, HEADER5
             TERMINAL R0, 0
             HALT             
REPUTATION:  LEA R1, ARRAYQ
             LDR R0, R1, #11
             PUTSP
             LEA R0, HEADER6
             TERMINAL R0, 0
             HALT
      

ANS1: .FILL    #0
ANS2: .FILL    #0
ANS3: .FILL    #0
ANS4: .FILL    #0
ANS5: .FILL    #0
ANS6: .FILL    #0

; STACK
TOP:    .FILL    STACK
STACK:  .BLKW    #100
REG2:   .FILL    #0
REG5:   .FILL    #0
REG6:   .FILL    #0
REG7:   .FILL    #0



ARRAYQ: .FILL Q1
        .FILL Q2 
        .FILL Q3
        .FILL Q4
        .FILL Q5
        .FILL Q6
        .FILL A1 
        .FILL A2
        .FILL A3
        .FILL A4
        .FILL A5
        .FILL A6
        
HEADER: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/1/1f/Taylor_Swift_-_Taylor_Swift.png', width=300>"
HEADER2: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/8/86/Taylor_Swift_-_Fearless.png', width=300>"
HEADER3: .STRINGZ "<img src='https://www.billboard.com/files/styles/900_wide/public/media/taylor-swift-speak-now-album-cover-2010-billboard-600x600.jpg', width=300>"
HEADER4: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/e/e8/Taylor_Swift_-_Red.png', width=300>"
HEADER5: .STRINGZ "<img src='https://upload.wikimedia.org/wikipedia/en/f/f6/Taylor_Swift_-_1989.png', width=300>"
HEADER6: .STRINGZ "<img src='https://www.billboard.com/files/media/Taylor-Swift-reputation-ART-2017-billboard-1548.jpg', width=300>"


ANS1: .FILL    #0
ANS2: .FILL    #0
ANS3: .FILL    #0
ANS4: .FILL    #0
ANS5: .FILL    #0
ANS6: .FILL    #0

ASCII: .FILL   #-48

ASCIIFUNC: LDI R1, ANS1, #0
           LDI R2, ANS2, #0
           LDI R3, ANS3, #0
           LDI R4, ANS4, #0
           LDI R5, ANS5, #0
           LDI R6, ANS6, #0
           
           LDI R0, ASCII, #0
           ADD R1, R1, R0
           ADD R2, R2, R0
           ADD R3, R3, R0
           ADD R4, R4, R0
           ADD R5, R5, R0
           ADD R6, R6, R0
           RET


Q1 .STRINGC "TSwift Quiz \n What would your ideal Friday night look like? \n 1. Go to local corn maze \n 2. Chill with Abigail at the Homecoming \n 3. Watch Twilight with your boyfriend \n 4. Hit up a One Direction Concert in London \n 5. Hang with your girl squad \n 6. Plot revenge on your enemies \n"
Q2 .STRINGC "\n What is your favorite color? \n 1. pink \n 2. yellow \n 3. purple \n 4. red \n 5. Anything Sepia toned \n 6. black \n"
Q3 .STRINGC "\n Which boyfriend would give you the best lyric material? \n 1. My high school crush \n 2. Joe Jonas \n 3. Taylor Lautner \n 4. Harry Styles \n 5. Calvin Harris \n 6. Do not need a boyfriend for good material! \n"
Q4 .STRINGC "\n Who would be your best friend in another life? \n 1. My mom \n 2. Abigail \n 3. Ellen Degeneres \n 4. Selena Gomez \n 5. Karlie Kloss \n 6. I do not have any friends \n"
Q5 .STRINGC "\n What is your favorite cookie flavor? \n 1. Sugar Cookies \n 2. Chocolate Chip \n 3. Peanut butter Cookie \n 4. Red Velvet \n 5. Snickerdoodle \n 6. Ginger Snap \n"
Q6 .STRINGC "\n Where do you want to live? \n 1. My hometown! \n 2. Nashville \n 3. Los Angeles \n 4. Rhode Island \n 5. New York City \n 6. London \n"

A1 .STRINGC "\n You are: Taylor Swift \n”
A2 .STRINGC "\n You are: Fearless \n”
A3 .STRINGC "\n You are: Speak Now \n”
A4 .STRINGC "\n You are: Red \n”
A5 .STRINGC "\n You are: 1989 \n”
A6 .STRINGC "\n You are: Reputation \n”

PUSH:  STI R2, REG2
       STI R5, REG5
       STI R6, REG6
       LEA R2, STACK
       STI R2, TOP
       LDI R6, TOP            ;; R6 is now TOP of stack
       LDI R5, REG7, #0
       STR R5, R6, #0        ;; push R7 on stack (R6 is top of stack location)
       ADD R6, R6, #1        ;; incr
       ST R6, TOP            ;; save incremented TOP
       LDI R2, REG2
       LDI R5, REG5
       LDI R6, REG6
       RET

POP:   STI R5, REG5
       STI R6, REG6
       LDI R6, TOP          ;; R6 is TOP of stack
       ADD R6, R6, #-1     ;; decr
       LDI R5, R6, #0      ;; load into R7 into R3
       STI R5, REG7, #0     ;; put value of R7 into REG7
       ADD R6, R6, #-1     ;; decr
       STI R6, TOP          ;; save decremented TOP
       LDI R5, REG5
       LDI R6, REG6
       RET  


.END
# Out:
# Assemble error
#     line 225
#
# Not an instruction: "ANS1", mask 0b111111111, offset 839,  0b11001101101000, ref x3021

# %%
%exe
# Out:
# TSwift Quiz
#  What would your ideal Friday night look like?
#  1. Go to local corn maze
#  2. Chill with Abigail at the Homecoming
#  3. Watch Twilight with your boyfriend
#  4. Hit up a One Direction Concert in London
#  5. Hang with your girl squad
#  6. Plot revenge on your enemies
#
# Input a character>
# Keyboard Interrupt!

# %%
%dis
# Out:
# ...
# Memory disassembled:
# ...
#            x3000: xE257  LEA R1, ARRAYQ                            [line: 3]
#            x3001: x6040  LDR R0, R1, 0                             [line: 4]
#            x3002: xF024  PUTSP                                     [line: 5]
#            x3003: xF023  IN                                        [line: 6]
#            x3004: x304D  ST R0, ANS1                               [line: 7]
#            x3005: x6041  LDR R0, R1, 1                             [line: 9]
#            x3006: xF024  PUTSP                                     [line: 10]
#            x3007: xF023  IN                                        [line: 11]
#            x3008: x304A  ST R0, ANS2                               [line: 12]
#            x3009: x6042  LDR R0, R1, 2                             [line: 14]
#            x300A: xF024  PUTSP                                     [line: 15]
#            x300B: xF023  IN                                        [line: 16]
# ...
